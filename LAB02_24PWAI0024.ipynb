# %% [markdown]
# # LAB REPORT 02

# %% [markdown]
# ## Task:01
# ## User Info using f-strings

# %%
# user information
name=input("enter your full name:")
color=input("enter your favorite color:")
year=int(input("enter your birth year:"))
# current year
current = 2026
# age calculate
age=current - year
# result print
print(f"Welcome,{name}!")
print(f"Your favorite color is {color}")
print(f"You were born in {year} and you are {age} years old in {current}")
# Out:
# enter your full name: Nabeeha Najeeb
# enter your favorite color: purple
# enter your birth year: 2004
# Welcome,Nabeeha Najeeb !
# Your favorite color is purple
# You were born in 2004 and you are 22 years old in 2026

# %% [markdown]
# ## Task:02
# ## Simple Calculator

# %%
# Taking two numbers from user
num1=float(input("enter 1st number:"))
num2=float(input("enter 2nd number:"))
# Asking for operation
operator=input("enter operation (+ - * / ** %):")
# Checking operator validity
if operator not in ["+", "-", "*", "/", "**", "%"]:
    print("invalid operator")
elif operator=="+":
    result=num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator=="-":
    result=num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator=="*":
    result=num1 * num2
    print(f"{num1} * {num2} = {result}")
elif operator=="/":
    if num2==0:
        print("cannot divide by 0")
    else:
        result=num1/num2
        print(f"{num1}/{num2}={result:.2f}")
elif operator=="**":
    result=num1 ** num2
    print(f"{num1} ** {num2} = {result:.2f}")
elif operator=="%":
    result=num1 % num2
    print(f"{num1} % {num2} = {result}")

# %% [markdown]
# ## Task:03
# ## Challenge A : Even/Odd & Multiple Checker

# %%
start = int(input("enter starting number: "))
end = int(input("enter ending number: "))
num = start
while num <= end:
    # Skip numbers divisible by 7
    if num % 7 == 0:
        num += 1
        continue
    if num % 2 == 0 and num % 5 == 0:
        print(f"{num} -> Even & Multiple of 5!!")
    elif num % 2 == 0:
        print(f"{num} -> Even")
    elif num % 5 == 0:
        print(f"{num} -> Multiple of 5!")
    else:
        print(num)
    num += 1
# Out:
# enter starting number:  2
# enter ending number:  6
# 2 -> Even
# 3
# 4 -> Even
# 5 -> Multiple of 5!
# 6 -> Even

# %% [markdown]
# ## Task:03
# ## Challenge B : Password Strength Checker

# %%
password = input("enter your password: ")
# Check length
if len(password) < 6:
    print("your password is too short!!")
else:
    has_digit = False
    has_upper = False
    # Checking each character
    for char in password:
        if char.isdigit():
            has_digit = True
        if char.isupper():
            has_upper = True
    if not has_digit:
        print("add at least 1 num")
    elif not has_upper:
        print("add at least one capital letter")
    else:
        print("strong password!!")
# Out:
# enter your password:  1314n
# your password is too short!!
